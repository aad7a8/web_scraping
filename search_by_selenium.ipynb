# %% [markdown]
# # selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗
options.add_argument("--incognito") # 無痕模式
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

# url = 'https://24h.pchome.com.tw/'
url = 'https://24h.pchome.com.tw/search/?q='
query = '筆電'

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)

# %%
# query = 'upc700w' # 2 items
# query = 'qwurg' # no item

# %%
driver.get(url + query)

# %%
# e = driver.find_element(By.CLASS_NAME, 'form-control').send_keys('python')
# driver.find_element(By.CSS_SELECTOR, "input[data-gtm-index='搜尋欄位-搜尋點擊']").send_keys("Python")

# driver.find_element(By.CLASS_NAME, "c-search__input").send_keys("Python")

driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
'o-iconFonts o-iconFonts--arrowSolidRight'
driver.find_element(By.CSS_SELECTOR, '.o-iconFonts.o-iconFonts--arrowSolidRight').click()

# %%
import time
for i in range(5):
    time.sleep(2)
    
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    'o-iconFonts o-iconFonts--arrowSolidRight'
    driver.find_element(By.CSS_SELECTOR, '.o-iconFonts.o-iconFonts--arrowSolidRight').click()

# %%
items = driver.find_elements(By.CSS_SELECTOR, 'div.c-listInfoGrid__body ul li>div.c-prodInfoV2')
print(len(items))
for item in items:
    # print(item.text)
    # try:
        url = item.find_element(By.CSS_SELECTOR, 'div>a').get_attribute('href')
        img = item.find_element(By.CSS_SELECTOR, 'div>img').get_attribute('src')
        price = item.find_element(By.CSS_SELECTOR, 'div.c-prodInfoV2__price').text
        name = item.find_element(By.CSS_SELECTOR, 'div.c-prodInfoV2__title').text

        print(url, img, price, name)
    # except Exception as e:
    #     continue
    # break
# Out:
# 40
# https://24h.pchome.com.tw/books/prod/DJBQ3A-D900D72ZM https://img.pchome.com.tw/cs/items/DJBQ3AD900D72ZM/000001_1642050527.jpg?width=480 $184 Ping Pong, Parkinson's and the Art of Staying in the Game(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ37-D900DE2XD https://img.pchome.com.tw/cs/items/DJBQ37D900DE2XD/000001_1642135695.jpg?width=480 $158 Ping Pong Dash!(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ37-D900DHDJT https://img.pchome.com.tw/cs/items/DJBQ37D900DHDJT/000001_1642176269.jpg?width=480 $158 Ping Pong Dash!(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ34-D900CEY9C https://img.pchome.com.tw/cs/items/DJBQ34D900CEY9C/000001_1641555925.jpg?width=480 $126 Under the Pong Pong Tree(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ38-D900CBFBF https://img.pchome.com.tw/cs/items/DJBQ38D900CBFBF/000001_1750959070.jpg?width=480 $216 The Wrong Pong(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ39-D900CG0W2 https://img.pchome.com.tw/cs/items/DJBQ39D900CG0W2/000001_1641570954.jpg?width=480 $120 SPIKE Prime 09. Ping-pong Building Instruction Guide(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ37-D900CYXBN https://img.pchome.com.tw/cs/items/DJBQ37D900CYXBN/000001_1641950776.jpg?width=480 $158 Ping Pong Dash!(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ37-D900CY9Z2 https://img.pchome.com.tw/cs/items/DJBQ37D900CY9Z2/000001_1641942674.jpg?width=480 $63 Ping Pong Dash!(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ37-D900D6UZU https://img.pchome.com.tw/cs/items/DJBQ37D900D6UZU/000001_1642047715.jpg?width=480 $63 Ping Pong Dash!(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ37-D900DBD8C https://img.pchome.com.tw/cs/items/DJBQ37D900DBD8C/000001_1642102805.jpg?width=480 $63 Ping Pong Dash!(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ68-D900HM0BN https://img.pchome.com.tw/cs/items/DJBQ68D900HM0BN/000001_1734409802.jpg?width=480 $210 Ping Pong(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ3F-D900IDRSV https://img.pchome.com.tw/cs/items/DJBQ3FD900IDRSV/000001_1758681067.jpg?width=480 $30 The FBA (Foundational Black American) Chess and Ping Pong Community Center.(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ38-D900DIGHT https://img.pchome.com.tw/cs/items/DJBQ38D900DIGHT/000001_1642189386.jpg?width=480 $126 The Flying Dragon with Ping, Pong and Pa Dul the Three Chinese Brothers(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ38-D900G7D5D https://img.pchome.com.tw/cs/items/DJBQ38D900G7D5D/000001_1680609089.jpg?width=480 $234 Cheese from Dimension Pong(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ35-D900F6DV0 https://img.pchome.com.tw/cs/items/DJBQ35D900F6DV0/000001_1655144128.jpg?width=480 $101 LGBT+ Pride Flags- The Ping Pong Ball Collection(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ68-D900GBMY1 https://img.pchome.com.tw/cs/items/DJBQ68D900GBMY1/000001_1683919805.jpg?width=480 $89 Mei Lin la campionessa del ping pong(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ39-D900GT25K https://img.pchome.com.tw/cs/items/DJBQ39D900GT25K/000001_1699286993.jpg?width=480 $314 The Ping Pong Player and the Professor(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ37-D900DV53U https://img.pchome.com.tw/cs/items/DJBQ37D900DV53U/000001_1642567080.jpg?width=480 $158 Ping Pong Dash!(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ37-D900DQ22P https://img.pchome.com.tw/cs/items/DJBQ37D900DQ22P/000001_1642385660.jpg?width=480 $63 Ping Pong Dash!(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ37-D900DFG3V https://img.pchome.com.tw/cs/items/DJBQ37D900DFG3V/000001_1642152584.jpg?width=480 $63 Ping Pong Dash!(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ37-D900D4BUD https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg $63 Ping Pong Dash!(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ37-D900D6Z7S https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg $63 Ping Pong Dash!(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ37-D900DBH9I https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg $63 Ping Pong Dash!(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ37-D900CUL0Q https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg $126 Ping Pong Dash!(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ37-D900CUBZW https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg $63 Ping Pong Dash!(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ37-D900CQ7J4 https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg $63 Ping Pong Dash!(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ37-D900CS07L https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg $63 Ping Pong Dash!(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ39-D900CM7ZC https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg $485 Everything You Know Is Pong(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ37-D900CN9Y2 https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg $63 Ping Pong Dash!(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ37-D900CERUV https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg $63 Ping Pong Dash!(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ37-D900CINZI https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg $63 Ping Pong Dash!(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ37-D900CA77X https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg $63 Ping Pong Dash!(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ37-D900CBOOX https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg $63 Ping Pong Dash!(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ37-D900CG035 https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg $158 Ping Pong Dash!(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ37-D900CF46Y https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg $63 Ping Pong Dash!(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ37-D900CHHBA https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg $63 Ping Pong Dash!(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ33-D900CJ34Q https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg $147 How to Start a Hobby in Table Tennis - Ping Pong(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ68-D900J45AK https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg $239 Book Betting Theory nel Ping Pong(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ3Z-D900ITF9X https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg $310 El método ping pong(Kobo/電子書)
# https://24h.pchome.com.tw/books/prod/DJBQ88-D900J6JWH https://img.pchome.com.tw/fs/img/h24/new/index/v1/images/img/mobile_loading.svg $299 Ping-Pong(Kobo/電子書)

# %%
import time
items = driver.find_elements(By.CSS_SELECTOR, 'div.c-listInfoGrid__body ul li>div.c-prodInfoV2')
print(len(items))
last = items[-1]
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    'o-iconFonts o-iconFonts--arrowSolidRight'
    driver.find_element(By.CSS_SELECTOR, '.o-iconFonts.o-iconFonts--arrowSolidRight').click()
    
    time.sleep(2)

    items = driver.find_elements(By.CSS_SELECTOR, 'div.c-listInfoGrid__body ul li>div.c-prodInfoV2')
    print(len(items))
    if last == items[-1]:
        break
    last = items[-1]

# %%
import time
items = driver.find_elements(By.CSS_SELECTOR, 'div.c-listInfoGrid__body ul li>div.c-prodInfoV2')
print(len(items))
last = items[-1]
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    'o-iconFonts o-iconFonts--arrowSolidRight'
    driver.find_element(By.CSS_SELECTOR, '.o-iconFonts.o-iconFonts--arrowSolidRight').click()
    
    time.sleep(2)

    items = driver.find_elements(By.CSS_SELECTOR, 'div.c-listInfoGrid__body ul li>div.c-prodInfoV2')
    print(len(items))
    if last == items[-1]:
        print('break')
        break
    last = items[-1]
# Out:
# 40
# 40
# 40
# 33
# 33
# break

# %%
# only 1 page

# %%
# no item
