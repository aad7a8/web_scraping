# %% [markdown]
# # selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗
options.add_argument("--incognito") # 無痕模式
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

# url = 'https://24h.pchome.com.tw/'
url = 'https://24h.pchome.com.tw/search/?q='
query = '筆電'

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)

# %%
query = 'upc700w' # 2 items
# query = 'qwurg' # no item
query = 'qwur' # no item 4 recommend
query = 'ufc700' # no smae item but similar items

# %%
driver.get(url + query)

# %%
# e = driver.find_element(By.CLASS_NAME, 'form-control').send_keys('python')
# driver.find_element(By.CSS_SELECTOR, "input[data-gtm-index='搜尋欄位-搜尋點擊']").send_keys("Python")

# driver.find_element(By.CLASS_NAME, "c-search__input").send_keys("Python")

driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
'o-iconFonts o-iconFonts--arrowSolidRight'
driver.find_element(By.CSS_SELECTOR, '.o-iconFonts.o-iconFonts--arrowSolidRight').click()

# %%
import time
for i in range(5):
    time.sleep(2)
    
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    'o-iconFonts o-iconFonts--arrowSolidRight'
    driver.find_element(By.CSS_SELECTOR, '.o-iconFonts.o-iconFonts--arrowSolidRight').click()

# %%
items = driver.find_elements(By.CSS_SELECTOR, 'div.c-listInfoGrid__body ul li>div.c-prodInfoV2')
print(len(items))
for item in items:
    # print(item.text)
    # try:
        url = item.find_element(By.CSS_SELECTOR, 'div>a').get_attribute('href')
        img = item.find_element(By.CSS_SELECTOR, 'div>img').get_attribute('src')
        price = item.find_element(By.CSS_SELECTOR, 'div.c-prodInfoV2__price').text
        name = item.find_element(By.CSS_SELECTOR, 'div.c-prodInfoV2__title').text

        print(url, img, price, name)
    # except Exception as e:
    #     continue
    # break
# Out:
# 0

# %%
import time
items = driver.find_elements(By.CSS_SELECTOR, 'div.c-listInfoGrid__body ul li>div.c-prodInfoV2')
print(len(items))
last = items[-1]
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    'o-iconFonts o-iconFonts--arrowSolidRight'
    driver.find_element(By.CSS_SELECTOR, '.o-iconFonts.o-iconFonts--arrowSolidRight').click()
    
    time.sleep(2)

    items = driver.find_elements(By.CSS_SELECTOR, 'div.c-listInfoGrid__body ul li>div.c-prodInfoV2')
    print(len(items))
    if last == items[-1]:
        break
    last = items[-1]

# %%
import time
items = driver.find_elements(By.CSS_SELECTOR, 'div.c-listInfoGrid__body ul li>div.c-prodInfoV2')
print(len(items))
# print(type(items))
last = items[-1]
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    'o-iconFonts o-iconFonts--arrowSolidRight'
    driver.find_element(By.CSS_SELECTOR, '.o-iconFonts.o-iconFonts--arrowSolidRight').click()
    
    time.sleep(2)

    items = driver.find_elements(By.CSS_SELECTOR, 'div.c-listInfoGrid__body ul li>div.c-prodInfoV2')
    print(len(items))
    if last == items[-1]:
        print('break')
        break
    last = items[-1]
# Out:
# 45
# <class 'list'>
# 45
# 45
# 45
# 45
# 45
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[27], line 13
#       9 driver.find_element(By.CSS_SELECTOR, '.o-iconFonts.o-iconFonts--arrowSolidRight').click()
#      11 time.sleep(2)
# ---> 13 items = driver.find_elements(By.CSS_SELECTOR, 'div.c-listInfoGrid__body ul li>div.c-prodInfoV2')
#      14 print(len(items))
#      15 if last == items[-1]:
#
# File c:\Users\aad7a\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\webdriver.py:967, in WebDriver.find_elements(self, by, value)
#     963     return self.execute_script(find_element_js, by.to_dict())
#     965 # Return empty list if driver returns null
#     966 # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 967 return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#
# ...

# %%
# only 1 page
try:
    # driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    e = driver.find_element(By.CSS_SELECTOR, '.o-iconFonts.o-iconFonts--arrowSolidRight')
    print(e)
    e.click()
except Exception as e:
    print('no more page')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="56b71bfc8ef3772c8ff8752d4ef11739", element="f.8999171A6E50D314E90D1086C37AEB10.d.62475E7124ECDE03F8E184F19584CA18.e.13340")>

# %%
# no item
try:
    e = driver.find_element(By.CSS_SELECTOR, 'section.u-mb24')
    print(e)
except Exception as e:
    print('no item not found section')
items = driver.find_elements(By.CSS_SELECTOR, 'div.c-listInfoGrid__body ul li>div.c-prodInfoV2')
print(len(items))
# Out:
# no item not found section
# 2
